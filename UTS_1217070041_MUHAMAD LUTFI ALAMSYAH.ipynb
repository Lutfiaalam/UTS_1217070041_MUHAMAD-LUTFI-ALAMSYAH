# %% [markdown]
# # **UTS PENGOLAHAN CITRA**
#
# Tuliskan kode program dari instruksi yang diperintahkan

# %% [markdown]
# 1. Tuliskan kode program untuk menampilkan gambar dengan library open CV (Poin 5)
#
# Note: Gambar dibebaskan

# %%
# 1217070041 Muhamad Lutfi Alamsyah
import cv2

png = cv2.imread('mobil.jpg',cv2.IMREAD_COLOR)

cv2.imshow('foto',png)
cv2.waitKey(0)
cv2.destroyAllWindows()

# %% [markdown]
# 2. Tampilkan tipe data gambar yang disimpan (Poin: 2)

# %%
# 1217070041 Muhamad Lutfi Alamsyah
import cv2

png = cv2.imread('mobil.jpg',cv2.IMREAD_COLOR)

# menyimpan dengan tipe data gambar png 
cv2.imwrite('mobil.jpg',png)

cv2.imshow('foto',png)
cv2.waitKey(0)
cv2.destroyAllWindows()

# %% [markdown]
# 3.  Cobalah gunakan library Matplotlib untuk menampilkan gambar (Poin: 5)

# %%
# 1217070041 Muhamad Lutfi Alamsyah
import matplotlib.pyplot as plt

png = cv2.imread('mobil.jpg')

plt.imshow(png)
plt.axis('on')  
plt.show()

# %% [markdown]
# 4. Buatlah kode program perintah lain yang dapat digunakan untuk mengakses properti citra sepert menampilkan resolusi gambar, menampilkan ukuran data media penyimpan, menampilkan image data type (kedalaman bit) (Poin: 5)

# %%
# 1217070041 Muhamad Lutfi Alamsyah
import cv2

png = cv2.imread('mobil.jpg')

resolusi = png.shape[:3]
ukuran_gambar = png.size
datatype = img.dtype

print(png.shape)
print(png.size)
print(png.dtype)

cv2.imshow('foto',png)
cv2.waitKey(0)
cv2.destroyAllWindows()
# Out:
# (899, 1600, 3)
# 4315200
# uint8

# %% [markdown]
# 5. Tuliskan kode program untuk citra dipecah pada band penyusunnya (Poin: 9)

# %%
# 1217070041 Muhamad Lutfi Alamsyah
import cv2

img = cv2.imread('mobil.jpg')
b,g,r = cv2.split(png)

cv2.imshow('blue',b)
cv2.imshow('green',g)
cv2.imshow('red',r)
cv2.waitKey(0)
# Out:
# -1

# %% [markdown]
# 6. Tampilkan gambar dari channel band biru / Blue Channel, green dan red (Poin: 9)

# %%
# 1217070041 Muhamad Lutfi Alamsyah
import matplotlib.pyplot as plt
import cv2
\
original = cv2.imread('mobil.jpg')

blue = original.copy()
blue[:, :, 1] = 0
blue[:, :, 2] = 0

green = original.copy()
green[:, :, 0] = 0
green[:, :, 2] = 0

red = original.copy()
red[:, :, 0] = 0
red[:, :, 1] = 0

plt.figure(figsize=(10, 10))

plt.subplot(2, 2, 1)
plt.imshow(original)
plt.title("Original")

plt.subplot(2, 2, 2)
plt.imshow(blue)
plt.title("Blue Channel")

plt.subplot(2, 2, 3)
plt.imshow(green)
plt.title("Green Channel")

plt.subplot(2, 2, 4)
plt.imshow(red)
plt.title("Red Channel")

plt.tight_layout()
plt.show()

# %% [markdown]
# 7. Tuliskan kode program untuk konversi BGR dari variable gambar ke colorspace HSV (Poin:5)

# %%
# 1217070041 Muhamad Lutfi Alamsyah
import cv2

png = cv2.imread('mobil.jpg')
hsv = cv2.cvtColor(png, cv2.COLOR_BGR2HSV)

cv2.imshow('foto',hsv)
cv2.waitKey(0)
cv2.destroyAllWindows()

# %% [markdown]
# 8. Pisahkan/Pecah hue, saturation dan value (Poin: 10)

# %%
# 1217070041 Muhamad Lutfi Alamsyah
import cv2

foto = cv2.imread('mobil.jpg')
hsv = cv2.cvtColor(foto, cv2.COLOR_BGR2HSV)

cv2.imshow('Hue', hsv[:,:,0])
cv2.imshow('Saturation', hsv[:,:,1])
cv2.imshow('Value', hsv[:,:,2])


cv2.waitKey(0)
cv2.destroyAllWindows()

# %% [markdown]
# 9. Tampilkan gambar hue channel, Saturation, dan Value (Poin 10)

# %%
# 1217070041 Muhamad Lutfi Alamsyah
import cv2

foto = cv2.imread('mobil.jpg')
hsv = cv2.cvtColor(foto, cv2.COLOR_BGR2HSV)

cv2.imshow('Hue', hsv[:,:,0])

cv2.waitKey(0)
cv2.destroyAllWindows()

# %% [markdown]
# 10. Setelah melakukan konversi BGR ke HSV kemudian tampilkan histogram untuk Band Merah/Red Channel, Hijau/Green Channel dan Biru/Blue channel (boleh menggunakan Matplotlib atau cv2.imshow) (Poin: 10)

# %%
# 1217070041 Muhamad Lutfi Alamsyah
import cv2
import matplotlib.pyplot as plt

png = cv2.imread('mobil.jpg')

hist_r, bins_r = np.histogram(png[:,:,0].ravel(),256,[0,256])
hist_g, bins_g = np.histogram(png[:,:,1].ravel(),256,[0,256])
hist_b, bins_b = np.histogram(png[:,:,2].ravel(),256,[0,256])

plt.figure(figsize=(10, 6))
plt.plot(hist_r, color='r', label='R')
plt.plot(hist_g, color='g', label='G')
plt.plot(hist_b, color='b', label='B')

plt.title('Histogram')
plt.xlabel('Intensitas')
plt.ylabel('Frekuensi')

plt.legend()
plt.grid()
plt.show()

# %% [markdown]
# 11. Tampilkan Histogram untuk channel hue, saturation dan value (poin: 5)

# %%
# 1217070041 Muhamad Lutfi Alamsyah
import cv2
import matplotlib.pyplot as plt

foto = cv2.imread('mobil.jpg')

hsv = cv2.cvtColor(foto, cv2.COLOR_BGR2HSV)

colors = ['r', 'g', 'b']
labels = ['H', 'S', 'V']

plt.figure(figsize=(10, 6))

for i in range(3):
    hist = cv2.calcHist([hsv], [i], None, [256], [0, 256])
    plt.plot(hist, color=colors[i], label=labels[i])

plt.title('HSV Histogram')
plt.xlabel('Intensitas')
plt.ylabel('Frekuensi')
plt.legend()
plt.grid()
plt.show()

# %% [markdown]
# 12. Menaikan brighness dengan menambahkan nilai konstanta = 100. Tampilkan gambar sebelum brightness dan sesudah (poin: 10)

# %%
# 1217070041 Muhamad Lutfi Alamsyah
import cv2
import numpy as np
import matplotlib.pyplot as plt

foto = cv2.imread("mobil.jpg")

def modify_brightness(image, brightness):
    
    modified_image = np.array(image, dtype=np.int16)
    modified_image += brightness
    modified_image = np.clip(modified_image, 0, 255)
    modified_image = np.array(modified_image, dtype=np.uint8)
    return modified_image

bright_0 = modify_brightness(foto, 0)
plt.imshow(bright_0)
plt.title("Brightness 0")
plt.show()

bright_100 = modify_brightness(foto, 100)
plt.imshow(bright_100)
plt.title("Brightness 100")
plt.show()

# %% [markdown]
# 13. Putar gambar 90 derajat dan tampilkan (poin:10)

# %%
# 1217070041 Muhamad Lutfi Alamsyah
import cv2

foto = cv2.imread("mobil.jpg")

rotasimatriks = cv2.getRotationMatrix2D((foto.shape[1] / 2, foto.shape[0] / 2), -90, 0.5)
rotasigambar = cv2.warpAffine(foto, rotasimatriks, (foto.shape[1], foto.shape[0]))

cv2.imshow('Citra Rotasi', rotasigambar)
cv2.waitKey(0)
cv2.destroyAllWindows()

# %% [markdown]
# 14. Normalisasikan gambar dan tampilkan historgramnya (poin 5)

# %%
# 1217070041 Muhamad Lutfi Alamsyah
import cv2
import numpy as np
import matplotlib.pyplot as plt


def show_image(image, title='image', cmap_type='gray'):
    plt.imshow(image, cmap=cmap_type)
    plt.title(title)
    plt.axis('off')
    plt.show()


def calculate_normalized_histogram(image):
    histogram, _ = np.histogram(image, bins=256, range=(0,256))
    total_pixels = image.size
    normalized_histogram = histogram / total_pixels
    return normalized_histogram

image_path = 'mobil.jpg'
image = cv2.imread(image_path, cv2.IMREAD_GRAYSCALE)

show_image(image, title='Normalisasi Citra')

normalized_histogram = calculate_normalized_histogram(image)
plt.bar(range(256), normalized_histogram, color='black')
plt.title('Normalisasi Histogram Citra')
plt.xlabel('Intensitas Pixel')
plt.ylabel('Distribusi Probabilitas')
plt.show()
